# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#These libraries are reqyured to manage the servicedesk dataset
# Numpy: used for large, multi-dimensional arrays and matrices, and for high-level mathematical functions
# Pandas: used for data manipulation and analysis
# matplotlib: used for visualisation and plotting graph/image/etc
# sklearn for splitting training data
# sklearn for linear regression model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as skl_lm
from sklearn.model_selection import train_test_split

# %%
# Import the service desk dataset
# head visualise the first five rows of the dataset
servicedesk = pd.read_csv('Dataset3.csv')
servicedesk.head()
# Out:
#     State  Priority  Assigned Group  Severity  P1 Incident  Urgency  Made SLA  \
# 0  Closed         4               1         3            0        4         1
# 1  Closed         3               1         3            0        3         1
# 2  Closed         3               2         3            0        3         1
# 3  Closed         3               2         3            0        3         1
# 4  Closed         3               2         3            0        3         1
#
#    Reassignment count
# 0                   1
# 1                   2
# 2                   1
# 3                   4
# 4                   1

# %%
#explore continious feature
servicedesk.describe()
# Out:
#           Priority  Assigned Group  Severity  P1 Incident      Urgency  \
# count  4518.000000     4518.000000    4518.0  4518.000000  4518.000000
# mean      3.027003        2.066180       3.0     0.014830     3.026782
# std       0.362238        0.663614       0.0     0.120884     0.362560
# min       1.000000        1.000000       3.0     0.000000     1.000000
# 25%       3.000000        2.000000       3.0     0.000000     3.000000
# 50%       3.000000        2.000000       3.0     0.000000     3.000000
# 75%       3.000000        3.000000       3.0     0.000000     3.000000
# max       4.000000        3.000000       3.0     1.000000     4.000000
#
#           Made SLA  Reassignment count
# count  4518.000000         4518.000000
# mean      0.948207            2.180832
# std       0.221633            1.779602
# min       0.000000            0.000000
# 25%       1.000000            1.000000
# 50%       1.000000            2.000000
# 75%       1.000000            3.000000
# ...

# %%
servicedesk.groupby('Made SLA').mean()
# Out:
#           Priority  Assigned Group  Severity  P1 Incident   Urgency  \
# Made SLA
# 0         2.948718        2.064103       3.0     0.047009  2.948718
# 1         3.031279        2.066293       3.0     0.013072  3.031046
#
#           Reassignment count
# Made SLA
# 0                   2.132479
# 1                   2.183473

# %%
servicedesk.groupby('P1 Incident').mean()
# Out:
#              Priority  Assigned Group  Severity   Urgency  Made SLA  \
# P1 Incident
# 0            3.052348        2.066277       3.0  3.052123  0.949899
# 1            1.343284        2.059701       3.0  1.343284  0.835821
#
#              Reassignment count
# P1 Incident
# 0                      2.178836
# 1                      2.313433

# %%
servicedesk.groupby('Urgency').mean()
# Out:
#          Priority  Assigned Group  Severity  P1 Incident  Made SLA  \
# Urgency
# 1        1.000000        2.000000       3.0     1.000000  0.826923
# 2        2.012195        2.036585       3.0     0.085366  0.817073
# 3        3.000000        2.092225       3.0     0.001962  0.953642
# 4        4.000000        1.739414       3.0     0.000000  0.931596
#
#          Reassignment count
# Urgency
# 1                  2.211538
# 2                  2.463415
# 3                  2.063527
# 4                  3.657980

# %%
servicedesk.groupby('Priority').mean()
# Out:
#           Assigned Group  Severity  P1 Incident   Urgency  Made SLA  \
# Priority
# 1               2.000000       3.0     1.000000  1.000000  0.826923
# 2               2.037037       3.0     0.086420  2.000000  0.814815
# 3               2.092202       3.0     0.001962  2.999755  0.953654
# 4               1.739414       3.0     0.000000  4.000000  0.931596
#
#           Reassignment count
# Priority
# 1                   2.211538
# 2                   2.481481
# 3                   2.063266
# 4                   3.657980

# %%
servicedesk.groupby('Severity').mean()
# Out:
#           Priority  Assigned Group  P1 Incident   Urgency  Made SLA  \
# Severity
# 3         3.027003         2.06618      0.01483  3.026782  0.948207
#
#           Reassignment count
# Severity
# 3                   2.180832

# %%
#drop all excess and continious features
cont_feat=['State', 'Severity', 'Assigned Group', 'Made SLA' , 'Priority' , 'Reassignment count']
servicedesk.drop(cont_feat, axis=1, inplace=True)
servicedesk.head()
# Out:
#    P1 Incident  Urgency
# 0            0        4
# 1            0        3
# 2            0        3
# 3            0        3
# 4            0        3

# %%
servicedesk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4518 entries, 0 to 4517
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   P1 Incident  4518 non-null   int64
#  1   Urgency      4518 non-null   int64
# dtypes: int64(2)
# memory usage: 70.7 KB

# %%
features = servicedesk.drop('P1 Incident', axis=1)
labels = servicedesk['P1 Incident']

#Stage one split 60% to training set and 40% to training set
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.4, random_state=42)
# Stage 2 split training set into 20% validation and 20% Test
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

# %%
print(len(labels), len(y_train), len(y_val), len(y_test))
# Out:
# 4518 2710 904 904

# %%
# import regression from sklearn
from sklearn.linear_model import LinearRegression

# %%
# reshape the X so it is a 2D array, which sklearn model usually expect
X = servicedesk['data'][:,0:3] # 'Urgency'
y = servicedesk['data'][:,3] # 'P1 Incident'
X.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data'
#
# The above exception was the direct cause of the following exception:
#
# ...
